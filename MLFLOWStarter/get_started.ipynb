# %% [markdown]
# ### MLFLOW Tracking server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://localhost:5000")

# %%
mlflow.set_experiment("Check local host connection")

with mlflow.start_run():
    mlflow.log_metric("test-1", 1.0)
    mlflow.log_metric("test-2", 2.0)
# Out:
# 🏃 View run intrigued-newt-189 at: http://localhost:5000/#/experiments/385130905894716914/runs/37d5a85e69384296baa46e54a31837b2
# 🧪 View experiment at: http://localhost:5000/#/experiments/385130905894716914
